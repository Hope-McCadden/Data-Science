# %%
# importing packages 'pandas'

import pandas as pd
import numpy as np
from datetime import datetime

# %%
# import 'Netflix Entertainment Dataset'

netflixM = pd.read_csv("netflix1.csv")
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000
netflixM.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country
# 0  United States, India, South Korea, China

# %% [markdown]
# # Beginning of Data Wrangling

# %%
# Value_counts() function to sum total TV_Shows and Movies

netflixM.StreamR.value_counts()
netflixM.StreamR.value_counts()
# Out:
# Movie      4265
# TV_Show    1969
# Name: StreamR, dtype: int64

# %%
# Remove 'TV Shows' rows from StreamR column

# Get names of indexes for which column Age has value 30
index = netflixM[ netflixM['StreamR'] == "TV_Show" ].index

# Delete these row indexes from dataFrame
netflixM.drop(index , inplace=True)
netflixM.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country
# 0  United States, India, South Korea, China

# %%
# Split and rename Columns

netflix_Movie = netflixM['listed_in'].str.split(',', expand=True).rename(columns = lambda x: 'Gengre'+str(x+1))
netflix_Movie.rename(columns = {'Gengre1' : 'International', 'Gengre2' : 'Sci-Fi', 'Gengre3' : 'Thrillers'}, inplace = True)
netflix_Movie.head(1)
# Out:
#               International     Sci-Fi Thrillers
# 0  Children & Family Movies   Comedies      None

# %%
# dummy coding netflix_Movie 'International' column
interDummy = pd.get_dummies(netflix_Movie['International'],drop_first=True)

# Concat 2 datasets 'netflixM' and 'movieDummy'
interMovie = pd.concat([netflixM, interDummy], axis = 1)
interMovie.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country  Anime Features  \
# 0  United States, India, South Korea, China               0
#
#    Children & Family Movies  Classic Movies  Comedies  Cult Movies  \
# 0                         1               0         0            0
#
#    Documentaries  Dramas  Horror Movies  Independent Movies  \
# 0              0       0              0                   0
#
#    International Movies  Movies  Music & Musicals  Romantic Movies  \
# 0                     0       0                 0                0
#
#    Sci-Fi & Fantasy  Sports Movies  Stand-Up Comedy  Thrillers
# 0                 0              0                0          0

# %%
# Rename columns for movie-International column
interMovie.rename(columns = {'Anime Features': 'Anime','Children & Family Movies' : 'Family', 'Classic Movies': 'Classic', 
                          'Cult Movies': 'Cult', 'Horror Movies': 'Horror', 'Independent Movies': 'Independent',
                          'Romantic Movies': 'Romantic', 'International Movies': 'International',
                          'Music & Musicals' :'Musicals', 'Sports Movies' : 'Sports', 'TV Dramas': 'Dramas', 
                          'TV Horror': 'Horror', 'Sci-Fi & Fantasy' : 'Sci-Fi'}, inplace = True)
interMovie.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country  Anime  Family  Classic  Comedies  \
# 0  United States, India, South Korea, China      0       1        0         0
#
#    Cult  Documentaries  Dramas  Horror  Independent  International  Movies  \
# 0     0              0       0       0            0              0       0
#
#    Musicals  Romantic  Sci-Fi  Sports  Stand-Up Comedy  Thrillers
# 0         0         0       0       0                0          0

# %% [markdown]
# # Sci-Fi Column

# %%
# dummy coding crime column
sciDummy = pd.get_dummies(netflix_Movie['Sci-Fi'], drop_first=True)

# Concat 2 datasets 'tv' and 'crimeDummy'
sciMovie = pd.concat([netflixM, sciDummy], axis=1)
sciMovie.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country   Children & Family Movies  \
# 0  United States, India, South Korea, China                          0
#
#     Classic Movies   Comedies   Cult Movies   Documentaries   Dramas  \
# 0                0          1             0               0        0
#
#     Faith & Spirituality   Horror Movies   Independent Movies  \
# 0                      0               0                    0
#
#     International Movies   LGBTQ Movies   Music & Musicals   Romantic Movies  \
# 0                      0              0                  0                 0
#
#     Sci-Fi & Fantasy   Sports Movies   Stand-Up Comedy   Thrillers
# 0                  0               0                 0           0

# %% [markdown]
# # Thrillers Column

# %%
# dummy coding netflix_Movie 'International' column
trillDummy = pd.get_dummies(netflix_Movie['Thrillers'],drop_first=True)

# Concat 2 datasets 'netflixM' and 'movieDummy'
trillMovie = pd.concat([netflixM, trillDummy], axis = 1)
trillMovie.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country   Classic Movies   Comedies  \
# 0  United States, India, South Korea, China                0          0
#
#     Cult Movies   Documentaries   Dramas   Faith & Spirituality  \
# 0             0               0        0                      0
#
#     Horror Movies   Independent Movies   International Movies   LGBTQ Movies  \
# 0               0                    0                      0              0
#
#     Music & Musicals   Romantic Movies   Sci-Fi & Fantasy   Sports Movies  \
# 0                  0                 0                  0               0
#
#     Thrillers
# 0           0

# %% [markdown]
# # Concat movies columns 'International', 'Sci-Fi', and 'Thrillers' dataframes

# %%
movieStreaming = pd.concat([interMovie, sciMovie, trillMovie], axis=1)
movieStreaming.head(1)
# Out:
#     show_id                                    title StreamR  \
# 0  81145628  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country  Anime  Family  Classic  Comedies  \
# 0  United States, India, South Korea, China      0       1        0         0
#
#    Cult  Documentaries  Dramas  Horror  Independent  International  Movies  \
# 0     0              0       0       0            0              0       0
#
#    Musicals  Romantic  Sci-Fi  Sports  Stand-Up Comedy  Thrillers   show_id  \
# 0         0         0       0       0                0          0  81145628
#
#                                      title StreamR  \
# 0  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country   Children & Family Movies  \
# 0  United States, India, South Korea, China                          0
#
#     Classic Movies   Comedies   Cult Movies   Documentaries   Dramas  \
# 0                0          1             0               0        0
#
#     Faith & Spirituality   Horror Movies   Independent Movies  \
# 0                      0               0                    0
#
#     International Movies   LGBTQ Movies   Music & Musicals   Romantic Movies  \
# 0                      0              0                  0                 0
#
#     Sci-Fi & Fantasy   Sports Movies   Stand-Up Comedy   Thrillers   show_id  \
# 0                  0               0                 0           0  81145628
#
#                                      title StreamR  \
# 0  Norm of the North: King Sized Adventure   Movie
#
#                             listed_in  date_added  release_year  \
# 0  Children & Family Movies, Comedies  2019-09-09          2019
#
#                                     country   Classic Movies   Comedies  \
# 0  United States, India, South Korea, China                0          0
#
#     Cult Movies   Documentaries   Dramas   Faith & Spirituality  \
# 0             0               0        0                      0
#
#     Horror Movies   Independent Movies   International Movies   LGBTQ Movies  \
# 0               0                    0                      0              0
#
#     Music & Musicals   Romantic Movies   Sci-Fi & Fantasy   Sports Movies  \
# 0                  0                 0                  0               0
#
#     Thrillers
# 0           0

# %%
# Exporting dataframe: netflix to an csv file.
movieStreaming.to_csv("movieStreaming.csv", index = False) #Python
